# %%
import pickle
import pandas as pd

# %%
'''file_read = open(r'Documents/Data/sim__saved_InputSpikes_DVTs__561_outSpikes__128_simulationRuns__6_secDuration__randomSeed_100520.p', "rb")
file_write = open(r'Documents/Data/this_shit.p', "ab")  # not sure if ab works. It's append binary I hope

for line_number, line in enumerate(file_read):
  file_write.write(line)

  if line_number > 1000:
    break

file_read.close()
file_write.close()'''
# Out:
# 'file_read = open(r\'Documents/Data/sim__saved_InputSpikes_DVTs__561_outSpikes__128_simulationRuns__6_secDuration__randomSeed_100520.p\', "rb")\nfile_write = open(r\'Documents/Data/this_shit.p\', "ab")  # not sure if ab works. It\'s append binary I hope\n\nfor line_number, line in enumerate(file_read):\n  file_write.write(line)\n\n  if line_number > 1000:\n    break\n\nfile_read.close()\nfile_write.close()'

# %%
import pickle

data = pickle.load(open(r'Documents/Data/sim__saved_InputSpikes_DVTs__561_outSpikes__128_simulationRuns__6_secDuration__randomSeed_100520.p', "rb"), encoding='latin1')

# %%
print(data.keys())
# Out:
# dict_keys(['Params', 'Results'])

# %%
df = pd.DataFrame(data)

df.head()
# Out:
#                                                                    Params  \
# useActiveDendrites                                                   True
# randomSeed                                                         100520
# collectAndSaveDVTs                                                   True
# numOutputSpikesPerSim   [15, 0, 2, 0, 7, 30, 0, 10, 1, 20, 13, 17, 3, ...
# averageOutputFrequency                                           0.730469
#
#                        Results
# useActiveDendrites         NaN
# randomSeed                 NaN
# collectAndSaveDVTs         NaN
# numOutputSpikesPerSim      NaN
# averageOutputFrequency     NaN

# %%
allSegments = df.loc['allSegmentsLength', 'Params']
allSegments
# Out:
# [24.200878230108255,
#  15.18219623504249,
#  21.66443601853558,
#  21.66443601853558,
#  21.66443601853558,
#  21.66443601853558,
#  21.66443601853558,
#  21.66443601853558,
#  21.66443601853558,
#  7.4556339070556366,
#  18.515165224051422,
#  18.515165224051422,
#  18.515165224051422,
#  18.515165224051422,
#  18.515165224051422,
#  21.46040779066964,
#  21.46040779066964,
#  21.46040779066964,
#  21.46040779066964,
#  21.46040779066964,
#  21.46040779066964,
#  21.46040779066964,
#  21.46040779066964,
#  21.46040779066964,
#  19.041740718656108,
#  19.041740718656108,
#  19.041740718656108,
#  19.041740718656108,
#  19.041740718656108,
#  19.041740718656108,
#  19.041740718656108,
#  27.13790848912385,
#  16.46306476701406,
#  15.947177517066333,
#  23.450676162709815,
#  23.450676162709815,
#  23.450676162709815,
#  8.079491562782842,
#  27.903255752955637,
#  21.06567240652129,
#  21.06567240652129,
#  21.06567240652129,
#  21.06567240652129,
#  21.06567240652129,
# ...
